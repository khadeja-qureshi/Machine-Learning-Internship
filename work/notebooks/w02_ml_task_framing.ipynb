# %% [markdown]
# <a href="https://colab.research.google.com/github/khadeja-qureshi/Machine-Learning-Internship/blob/main/work/notebooks/w02_ml_task_framing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-03 — Frame Your Lane as an ML Task
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/khadeja-qureshi/Machine-Learning-Internship/blob/main/work/notebooks/w02_ml_task_framing.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane as an ML task (type)
#
# *Classification, clustering, ranking, or scoring — which one, and why?*

# %% [markdown]
# I chose **Lane 2: Refresh / Content Opportunity Scoring**. This is primarily a **ranking/scoring** task because the goal is to prioritize webpages for review rather than simply classify them. The output will be a ranked list of webpages based on their refresh opportunity, allowing the content team to focus on the pages that are most likely to benefit from review. This supports better decision-making by helping teams allocate their limited review time effectively.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. Target or proxy
#
# *What would you predict? Where does that label come from — observed outcome or a defined rule?*

# %% [markdown]
# For the starter dataset, I will use trend_direction as a proxy target. Pages labeled down will be treated as positive candidates for content review, while the remaining categories will initially be treated as non-declining.
#
# This is a proxy based on observed historical performance rather than proof that refreshing the page will improve future results. Because trend_direction defines the target, trend_direction, trend_pct, and any variables directly used to calculate them must not be included as model features.
#
# For the full warehouse dataset, the target should be measured in a future observation window. Features would be calculated before a cutoff date, and the decline outcome would be measured after that date to reduce leakage.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
import pandas as pd

df = pd.read_csv("/content_refresh_anonymized.csv")

df["trend_direction"].value_counts()
# Out:
# trend_direction
# down      16262
# stable     5962
# up         4388
# new        2236
# flat       1152
# Name: count, dtype: int64

# %% [markdown]
# ## 3. Success metric
#
# *One metric you can defend. What number means 'good'?*

# %% [markdown]
# The primary evaluation metric will be Precision@50 because the content team has limited capacity and is most concerned with the quality of the first 50 recommendations. Precision@50 measures the proportion of the top 50 recommended webpages that are genuinely relevant for review.
#
# A successful model should outperform the hand-written baseline on held-out clients. The starter baseline achieved a Precision@50 of 0.24, so a provisional success target is a Precision@50 of at least 0.60. This would mean that at least 30 of the top 50 recommendations are relevant for review.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 4. The unit of analysis, as a real dataframe
#
# *Load your lane's slice and show it: one row = one what?*

# %% [markdown]
# The unit of analysis is **one webpage (one content item)**. Each row in the dataset represents a single webpage and includes search, engagement, content, and performance metrics. These observations will be used to prioritize which pages should be reviewed first.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
import pandas as pd

df = pd.read_csv("/content_refresh_anonymized.csv")

print("Dataset shape:", df.shape)

df[[
    "content_id",
    "client_id",
    "content_type",
    "impressions_90d",
    "sessions_90d",
    "trend_direction"
]].head()
# Out:
# Dataset shape: (30000, 44)
#              content_id          client_id     content_type  impressions_90d  \
# 0  content_304f48230142  client_f369cb89fc  keyword article             3803
# 1  content_a1fb4e703a9e  client_4e07408562  keyword article            15320
# 2  content_9aa793d4d895  client_7f2253d7e2  keyword article            12581
# 3  content_331d6c4de07b  client_19581e27de  keyword article            11751
# 4  content_d99b7a2d90ca  client_3fdba35f04  keyword article            19140
#
#    sessions_90d trend_direction
# 0            17            down
# 1             9            down
# 2            11            down
# 3            78          stable
# 4           145            down

# %% [markdown]
# ## 5. Why ML beats a fixed rule here
#
# *What makes the pattern too messy for an if-statement?*

# %% [markdown]
# A simple rule such as "review every page with declining traffic" does not consider other important signals like impressions, CTR, average position, engagement, or content characteristics. Machine learning can combine multiple observable signals to identify pages that are most likely to benefit from review while reducing unnecessary work on healthy pages.
#
# The goal is to provide decision-support through a ranked list of content opportunities, not to replace human judgment or guarantee future search performance.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
df[[
    "impressions_90d",
    "clicks_90d",
    "ctr",
    "avg_position",
    "engagement_rate",
    "trend_direction"
]].head()
# Out:
#    impressions_90d  clicks_90d   ctr  avg_position  engagement_rate  \
# 0             3803          29  0.76          10.6             5.88
# 1            15320           7  0.05          20.3             0.00
# 2            12581          11  0.09          36.5             0.00
# 3            11751          58  0.49           6.2             1.28
# 4            19140          24  0.13          44.0             0.00
#
#   trend_direction
# 0            down
# 1            down
# 2            down
# 3          stable
# 4            down

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [x] Every section above is filled — markdown thinking AND the code that backs it
# - [x] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [x] No client names, URLs, or private queries anywhere
# - [x] My claims use careful words: observed, measured, directional, decision-support
# - [x] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
